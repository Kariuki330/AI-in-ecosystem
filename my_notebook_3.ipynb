# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import cv2 # Import OPenCV
import webcolors

# Training data: RGB values and their corresponding color labels
X = np.array([
    [255, 0, 0],    # Red
    [162, 255, 0], # Light Red
    [162, 17, 17], #Red Wine
    [152, 6, 6], #Blood Red
    [0, 255, 0],    # Green
    [18, 89, 135], # Dark Green
    [18, 135, 89], # Light Green
    [53, 169, 45], # Lime Green
    [18, 89, 13], # Lincoln Green
    [20, 142, 11], # Napier Green
    [0, 0, 255],    # Blue
    [36, 96, 143], # Light Navy Blue
    [17, 128, 212], #Water Blue
    [0, 0, 255], # Light Blue
    [22, 48, 177], # Egyptian Blue
    [255, 255, 0],  # Yellow
    [0, 255, 255],  # Cyan
    [255, 0, 255],  # Magenta
    [0, 0, 0],      # Black
    [255, 255, 255], # White
    [128, 0, 128], # purple
    [255, 165, 0], # orange
    [255, 192, 203], # pink
    [165, 42, 42], # Brown
])
y = np.array(['Red', 'Light Red', 'Red Wine', 'Blood Red', 'Green', 'Dark Green', 'Light Green', 'Lime Green', 'Lincoln Green', 'Napier Green', 'Blue', 'Light Navy Blue', 'Water Blue', 'Light Blue', 'Egyptian Blue', 'Yellow', 'Cyan', 'Magenta', 'Black', 'White', 'Purple', 'Orange', 'Pink', 'Brown'])

# Create and train the K-Nearest Neighbors classifier
model = KNeighborsClassifier(n_neighbors=1)
model.fit(X, y)

# Function to extract RGB values from an image using OpenCV
def get_rgb_from_image(image_path):
    """Extract the average RGB value from an image using OpenCV."""
    image = cv2.imread(image_path) # Read the image
    if image is None:
        raise FileNotFoundError(f"Image not found at path: {image_path}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # Convert BGR to RGB

    # convert image to grayscale for contour detection
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 50, 255, cv2.THRESH_BINARY) # Thresholding to get binary image

    # Find contours of particles in the image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    Results = [] # List to store the average color of each contour
    for contour in contours:
        #create a mask for the current particle
        mask = np.zeros_like(image)
        cv2.drawContours(mask, [contour], -1, (255, 255, 255), -1)

        # Extract the average color of the particle
        mask_image = cv2.bitwise_and(image, mask)
        avg_color = cv2.mean(mask_image, mask=cv2.cvtColor(mask, cv2.COLOR_RGB2GRAY))[:3]
        Results.append(avg_color)  # Append the average color to the results list

    return Results

# Function to match closest color name using webcolors
def get_color_name(RGB):
    try:
        return webcolors.rgb_to_name(tuple(RGB))
    except ValueError:
        return "Unknown Color"

# Function to test the model with a new color from an image
def test_model(image_path):
    """Test the model with a new color from an image."""
    try:
        avg_colors = get_rgb_from_image(image_path)  # Get average colors from the image
        results = []
        for avg_color in avg_colors:
            test_color = np.array(avg_color).reshape(1, -1)  # Reshape for prediction
            predicted_color = model.predict(test_color)

            # Get closest color name using webcolors
            closest_color = get_color_name(avg_color)

            results.append({
                "predicted_color": predicted_color[0],
                "closest_color": closest_color,
                "average_rgb": avg_color
            })

        return results
    except Exception as e:
        print(f"An error occurred: {e}")
        return []
    
# Test the function with an image
image_path = r"C:\Users\usr\Desktop\John python\john1.png"  # Replace with the correct path to your image
particle_colors = test_model(image_path)

# Print the results
for i, particle in enumerate(particle_colors, start=1):
    print(f"Particle {i}:")
    print(f"  Predicted color: {particle['predicted_color']}")
    print(f"  Closest color name: {particle['closest_color']}")
    print(f"  Average RGB: {particle['average_rgb']}")
# Out:
# Particle 1:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (244.66666666666666, 33.33333333333333, 32.33333333333333)
# Particle 2:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (164.0, 46.0, 52.0)
# Particle 3:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (196.66666666666666, 38.0, 28.0)
# Particle 4:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (201.5, 36.5, 26.5)
# Particle 5:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (161.4, 44.400000000000006, 36.800000000000004)
# Particle 6:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.66666666666669, 87.96969696969697, 93.06060606060606)
# Particle 7:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (241.0, 32.5, 29.5)
# Particle 8:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (211.42857142857142, 52.14285714285714, 49.57142857142857)
# Particle 9:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (167.11904761904762, 54.76190476190476, 45.11904761904761)
# Particle 10:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (185.75, 56.0625, 51.4375)
# Particle 11:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (192.5, 37.5, 32.5)
# Particle 12:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (239.6, 70.4, 70.88)
# Particle 13:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.88235294117646, 64.38235294117646, 69.6470588235294)
# Particle 14:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.03846153846155, 82.92307692307693, 85.76923076923077)
# Particle 15:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (168.88235294117646, 48.705882352941174, 36.64705882352941)
# Particle 16:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (219.0, 37.0, 37.0)
# Particle 17:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (240.98969072164948, 98.76288659793815, 104.31958762886597)
# Particle 18:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.2127659574468, 75.74468085106383, 78.97872340425532)
# Particle 19:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (206.0, 41.0, 39.5)
# Particle 20:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (169.52564102564102, 55.26923076923077, 48.08974358974359)
# Particle 21:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (168.5, 44.0, 38.5)
# Particle 22:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (156.25, 47.75, 45.75)
# Particle 23:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (243.5, 31.75, 40.5)
# Particle 24:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (184.0, 45.0, 26.5)
# Particle 25:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (193.25, 42.25, 34.25)
# Particle 26:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (221.0, 32.5, 27.0)
# Particle 27:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.25, 64.25, 63.5)
# Particle 28:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (237.4, 46.45, 48.25)
# Particle 29:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (178.0769230769231, 87.84615384615385, 100.3076923076923)
# Particle 30:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (189.2281879194631, 89.63087248322148, 85.31543624161074)
# Particle 31:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (239.8125, 71.09375, 71.3125)
# Particle 32:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (231.33333333333331, 35.0, 24.333333333333332)
# Particle 33:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (181.0, 46.0, 41.0)
# Particle 34:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.25, 60.96428571428571, 65.64285714285714)
# Particle 35:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (206.0, 85.24031007751938, 66.93023255813954)
# Particle 36:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (241.4181818181818, 73.07272727272726, 79.0909090909091)
# Particle 37:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (213.70000000000002, 49.0, 32.800000000000004)
# Particle 38:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.70731707317074, 61.29268292682927, 64.78048780487805)
# Particle 39:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (184.6, 67.5, 58.96666666666667)
# Particle 40:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (198.67857142857142, 85.63690476190476, 70.95833333333333)
# Particle 41:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (233.33333333333331, 45.5, 44.166666666666664)
# Particle 42:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (231.45454545454547, 83.0, 68.0909090909091)
# Particle 43:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.26605504587155, 99.7308868501529, 103.85626911314985)
# Particle 44:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (208.0, 41.0, 31.0)
# Particle 45:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (207.20689655172413, 77.39655172413794, 62.137931034482754)
# Particle 46:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (184.6595744680851, 77.64893617021276, 65.5)
# Particle 47:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (208.0919540229885, 62.54022988505747, 66.70114942528735)
# Particle 48:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (153.27272727272728, 58.18181818181819, 62.27272727272727)
# Particle 49:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (212.0, 40.0, 40.0)
# Particle 50:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (222.0, 29.0, 35.0)
# Particle 51:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (178.42857142857142, 55.14285714285714, 43.285714285714285)
# Particle 52:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (232.25333333333336, 84.45333333333333, 89.50666666666667)
# Particle 53:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (163.625, 55.75, 53.875)
# Particle 54:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (216.0, 33.0, 32.0)
# Particle 55:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (237.08333333333331, 62.916666666666664, 60.33333333333333)
# Particle 56:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (165.0, 45.5, 49.0)
# Particle 57:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (230.6923076923077, 69.11538461538461, 69.0)
# Particle 58:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.28571428571428, 69.21428571428571, 63.42857142857142)
# Particle 59:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (179.76086956521738, 93.65217391304347, 95.57608695652173)
# Particle 60:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (244.0, 28.0, 24.0)
# Particle 61:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (146.25, 47.25, 40.25)
# Particle 62:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (237.8, 72.9, 77.05000000000001)
# Particle 63:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (187.6764705882353, 63.73529411764706, 52.11764705882353)
# Particle 64:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (239.44444444444443, 54.166666666666664, 57.388888888888886)
# Particle 65:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (144.0, 65.0, 56.5)
# Particle 66:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (237.33333333333331, 34.33333333333333, 39.0)
# Particle 67:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.72413793103448, 100.86206896551724, 106.77011494252874)
# Particle 68:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (152.0, 41.0, 40.0)
# Particle 69:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (241.28048780487805, 85.75609756097562, 90.92682926829269)
# Particle 70:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (229.375, 63.125, 61.75)
# Particle 71:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (150.0, 48.0, 33.0)
# Particle 72:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (198.9529702970297, 95.89975247524752, 91.50742574257426)
# Particle 73:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (236.04255319148936, 87.82978723404256, 91.93617021276596)
# Particle 74:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (187.70588235294116, 105.92156862745098, 104.16666666666667)
# Particle 75:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (196.66433566433565, 65.85314685314685, 53.46853146853147)
# Particle 76:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (239.83333333333331, 56.916666666666664, 56.5)
# Particle 77:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (184.0, 44.0, 34.0)
# Particle 78:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (184.9506172839506, 99.93827160493827, 103.98765432098764)
# Particle 79:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (237.5, 67.54166666666666, 69.41666666666666)
# Particle 80:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (239.5, 62.25, 69.5)
# Particle 81:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (237.25714285714284, 98.02857142857142, 102.84285714285714)
# Particle 82:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (137.0, 45.0, 44.5)
# Particle 83:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (188.25, 47.0, 47.5)
# Particle 84:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (237.9426229508197, 88.12295081967214, 93.172131147541)
# Particle 85:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (230.5, 42.0, 39.25)
# Particle 86:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (168.2941176470588, 66.27450980392157, 65.0)
# Particle 87:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (182.11309523809524, 89.49404761904762, 88.02380952380952)
# Particle 88:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (158.83333333333331, 48.08333333333333, 39.75)
# Particle 89:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (209.25, 40.75, 24.5)
# Particle 90:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (173.40217391304347, 71.72826086956522, 67.97826086956522)
# Particle 91:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (198.1290322580645, 82.2258064516129, 69.2258064516129)
# Particle 92:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (184.0, 36.5, 32.5)
# Particle 93:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (236.6875, 68.25, 70.75)
# Particle 94:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (239.7142857142857, 38.857142857142854, 35.14285714285714)
# Particle 95:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (182.5735294117647, 79.68529411764706, 73.06764705882352)
# Particle 96:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (185.0, 42.666666666666664, 27.666666666666664)
# Particle 97:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (235.92307692307693, 53.07692307692308, 52.0)
# Particle 98:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (174.9041095890411, 67.38356164383562, 55.082191780821915)
# Particle 99:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (180.33333333333334, 71.15686274509804, 56.294117647058826)
# Particle 100:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (189.72972972972974, 67.62162162162163, 51.91891891891892)
# Particle 101:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (197.9692307692308, 77.76923076923077, 61.13846153846154)
# Particle 102:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.07407407407405, 84.38888888888889, 86.6111111111111)
# Particle 103:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (185.99095840867992, 77.82278481012658, 69.54249547920433)
# Particle 104:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (160.0, 51.0, 43.0)
# Particle 105:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (213.25454545454545, 105.65454545454546, 88.32727272727273)
# Particle 106:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (146.0, 43.0, 34.0)
# Particle 107:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (163.5, 50.25, 46.75)
# Particle 108:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (145.0, 44.0, 44.0)
# Particle 109:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (227.14285714285714, 65.71428571428571, 55.57142857142857)
# Particle 110:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (206.56737588652481, 62.07801418439716, 47.652482269503544)
# Particle 111:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (179.5, 42.5, 29.5)
# Particle 112:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (193.61194029850745, 68.99004975124377, 56.298507462686565)
# Particle 113:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (240.33333333333331, 37.5, 33.0)
# Particle 114:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (236.37037037037035, 67.7037037037037, 61.96296296296296)
# Particle 115:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (232.0, 33.0, 23.0)
# Particle 116:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (236.08626760563382, 87.29049295774648, 89.3556338028169)
# Particle 117:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (204.0185185185185, 73.75925925925925, 55.5)
# Particle 118:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.17241379310346, 85.98275862068965, 88.1896551724138)
# Particle 119:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (195.88741721854305, 70.89403973509934, 58.549668874172184)
# Particle 120:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (211.0, 40.0, 40.0)
# Particle 121:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (172.55428571428573, 76.95428571428572, 73.95428571428572)
# Particle 122:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (185.1320754716981, 92.47169811320754, 89.33962264150944)
# Particle 123:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (154.1818181818182, 47.81818181818182, 38.81818181818182)
# Particle 124:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (238.13333333333333, 50.0, 55.53333333333333)
# Particle 125:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (197.66666666666666, 42.33333333333333, 32.83333333333333)
# Particle 126:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (182.33962264150944, 71.39622641509433, 61.63207547169811)
# Particle 127:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (189.0, 37.0, 28.0)
# Particle 128:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (182.13750000000002, 94.42500000000001, 97.025)
# Particle 129:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (186.41304347826087, 78.05978260869566, 72.77173913043478)
# Particle 130:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (240.67924528301887, 97.66037735849056, 101.84905660377358)
# Particle 131:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (209.0, 39.5, 36.0)
# Particle 132:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (175.3487394957983, 77.78151260504201, 75.24369747899159)
# Particle 133:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (225.33333333333331, 40.0, 34.33333333333333)
# Particle 134:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (185.0, 71.14285714285714, 62.666666666666664)
# Particle 135:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (241.65625, 79.875, 83.953125)
# Particle 136:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (201.33333333333331, 71.75, 58.916666666666664)
# Particle 137:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (192.01250000000002, 81.66250000000001, 74.434375)
# Particle 138:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (237.80672268907563, 69.90336134453781, 75.24789915966386)
# Particle 139:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (240.54545454545456, 46.81818181818182, 44.63636363636364)
# Particle 140:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (184.88275862068966, 84.50344827586207, 69.1448275862069)
# Particle 141:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (237.52941176470588, 37.588235294117645, 39.8235294117647)
# Particle 142:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (167.4235294117647, 67.7764705882353, 67.65882352941176)
# Particle 143:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (240.11842105263156, 100.80263157894737, 107.26315789473684)
# Particle 144:
#   Predicted color: Pink
#   Closest color name: Unknown Color
#   Average RGB: (241.66019417475727, 113.33009708737863, 118.0388349514563)
# Particle 145:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (237.13333333333335, 70.62666666666667, 73.24000000000001)
# Particle 146:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (241.09523809523807, 68.95238095238095, 72.04761904761904)
# Particle 147:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (174.819209039548, 71.75141242937853, 66.22598870056497)
# Particle 148:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (235.73684210526315, 66.73684210526315, 67.21052631578947)
# Particle 149:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (180.8036809815951, 56.374233128834355, 46.96319018404908)
# Particle 150:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (173.7671232876712, 67.16438356164383, 52.71232876712328)
# Particle 151:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (172.78787878787878, 66.33333333333333, 63.06060606060606)
# Particle 152:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (236.5, 34.0, 34.5)
# Particle 153:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (186.1422351233672, 90.81277213352685, 86.25834542815674)
# Particle 154:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (179.55882352941177, 75.42647058823529, 62.25)
# Particle 155:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (238.08333333333331, 50.0, 50.75)
# Particle 156:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (239.9102564102564, 94.38461538461539, 99.42307692307692)
# Particle 157:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (240.26984126984127, 74.98412698412697, 80.93650793650794)
# Particle 158:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (177.33913043478262, 65.90434782608696, 60.36521739130435)
# Particle 159:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (228.875, 58.0, 46.5)
# Particle 160:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (177.72549019607843, 75.07843137254902, 69.65359477124183)
# Particle 161:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (175.88118811881188, 76.04950495049505, 72.08910891089108)
# Particle 162:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (152.5, 44.25, 36.625)
# Particle 163:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (241.3960396039604, 100.32673267326733, 105.76237623762377)
# Particle 164:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (237.12121212121212, 108.16666666666667, 109.84848484848486)
# Particle 165:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (239.01941747572815, 90.04854368932038, 95.2135922330097)
# Particle 166:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (168.76351351351352, 58.472972972972975, 51.054054054054056)
# Particle 167:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (239.84615384615384, 76.64102564102564, 79.17948717948718)
# Particle 168:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (240.36842105263156, 67.96491228070175, 72.1578947368421)
# Particle 169:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (236.74285714285713, 75.42857142857143, 76.48571428571428)
# Particle 170:
#   Predicted color: Red
#   Closest color name: Unknown Color
#   Average RGB: (235.60000000000002, 45.0, 45.900000000000006)
# Particle 171:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (242.11111111111111, 68.82222222222222, 73.93333333333334)
# Particle 172:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (193.4906976744186, 78.12093023255814, 66.8232558139535)
# Particle 173:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (165.79166666666666, 47.875, 43.416666666666664)
# Particle 174:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (239.06382978723403, 68.57446808510637, 69.76595744680851)
# Particle 175:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (156.52380952380952, 54.3095238095238, 46.71428571428571)
# Particle 176:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (178.1875, 65.95535714285714, 55.044642857142854)
# Particle 177:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (184.91171993911718, 84.91171993911719, 76.25570776255708)
# Particle 178:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (140.0, 43.0, 38.0)
# Particle 179:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (180.5, 40.125, 31.75)
# Particle 180:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (234.0909090909091, 62.45454545454545, 65.18181818181819)
# Particle 181:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (151.0, 40.0, 36.0)
# Particle 182:
#   Predicted color: Pink
#   Closest color name: Unknown Color
#   Average RGB: (240.79166666666666, 114.25, 117.91666666666666)
# Particle 183:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (239.16666666666666, 75.0, 79.75)
# Particle 184:
#   Predicted color: Pink
#   Closest color name: Unknown Color
#   Average RGB: (242.4, 110.67692307692309, 114.58461538461539)
# Particle 185:
#   Predicted color: Pink
#   Closest color name: Unknown Color
#   Average RGB: (241.5057915057915, 109.83397683397683, 114.77992277992279)
# Particle 186:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (237.52941176470588, 93.35294117647058, 94.70588235294117)
# Particle 187:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (245.75, 58.75, 63.5)
# Particle 188:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (188.141592920354, 96.83185840707965, 96.73008849557522)
# Particle 189:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (208.33333333333331, 60.285714285714285, 40.047619047619044)
# Particle 190:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (189.5909090909091, 65.77272727272728, 52.95454545454545)
# Particle 191:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (206.940350877193, 90.82573099415205, 74.93567251461988)
# Particle 192:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (211.75892857142856, 71.60714285714285, 52.95535714285714)
# Particle 193:
#   Predicted color: Brown
#   Closest color name: Unknown Color
#   Average RGB: (201.0, 88.41379310344827, 71.82758620689656)
